# %% [markdown]
# Problem statement: To build a CNN based model which can accurately detect melanoma. Melanoma is a type of cancer that can be deadly if not detected early. It accounts for 75% of skin cancer deaths. A solution which can evaluate images and alert the dermatologists about the presence of melanoma has the potential to reduce a lot of manual effort needed in diagnosis.

# %% [markdown]
# ### Importing all the important libraries

# %%
import pathlib
import tensorflow as tf
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import os
import PIL
from tensorflow import keras
from tensorflow.keras import layers
from tensorflow.keras.models import Sequential

# %% [markdown]
# This assignment uses a dataset of about 2357 images of skin cancer types. The dataset contains 9 sub-directories in each train and test subdirectories. The 9 sub-directories contains the images of 9 skin cancer types respectively.

# %% [markdown]
# ### (The Project was done in Google Colab to utilize the GPU capabilities provided by Google)

# %%
from google.colab import drive
drive.mount('/content/gdrive')
# Out:
# Mounted at /content/gdrive

# %%
# Path define


# Defining the path for train and test images
## Todo: Update the paths of the train and test dataset
data_dir_train = pathlib.Path("/content/gdrive/MyDrive/Datasets/Melanoma/Train")
data_dir_test = pathlib.Path('/content/gdrive/MyDrive/Datasets/Melanoma/Test')

# %%
image_count_train = len(list(data_dir_train.glob('*/*.jpg')))
print(image_count_train)
image_count_test = len(list(data_dir_test.glob('*/*.jpg')))
print(image_count_test)
# Out:
# 2239
# 118

# %% [markdown]
# ### Load using keras.preprocessing
#
# Let's load these images off disk using the helpful image_dataset_from_directory utility.

# %% [markdown]
# ### Create a dataset
#
# Define some parameters for the loader:

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# Use 80% of the images for training, and 20% for validation.

# %%
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='training',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 1792 files for training.

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
    data_dir_train,
    seed=123,
    validation_split = 0.2,
    subset='validation',
    image_size=(img_height, img_width),  
    batch_size=batch_size)
# Out:
# Found 2239 files belonging to 9 classes.
# Using 447 files for validation.

# %%
# Let's see the class names. These correspond to the directory names in alphabetical order.
class_names = train_ds.class_names
print(class_names)
# Out:
# ['actinic keratosis', 'basal cell carcinoma', 'dermatofibroma', 'melanoma', 'nevus', 'pigmented benign keratosis', 'seborrheic keratosis', 'squamous cell carcinoma', 'vascular lesion']

# %% [markdown]
# ### Visualize the data
# #### Todo, create a code to visualize one instance of all the nine classes present in the dataset

# %%
import matplotlib.pyplot as plt

### your code goes here, you can use training or validation data to visualize



plt.figure(figsize=(10, 10))
for images, labels in train_ds.take(1):
  for i in range(9):
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(images[i].numpy().astype("uint8"))
    plt.title(class_names[labels[i]])
    plt.axis("off")

# %% [markdown]
# The `image_batch` is a tensor of the shape `(32, 180, 180, 3)`. This is a batch of 32 images of shape `180x180x3` (the last dimension refers to color channels RGB). The `label_batch` is a tensor of the shape `(32,)`, these are corresponding labels to the 32 images.

# %% [markdown]
# `Dataset.cache()` keeps the images in memory after they're loaded off disk during the first epoch.
#
# `Dataset.prefetch()` overlaps data preprocessing and model execution while training.

# %%
AUTOTUNE = tf.data.experimental.AUTOTUNE
train_ds = train_ds.cache().shuffle(1000).prefetch(buffer_size=AUTOTUNE)
val_ds = val_ds.cache().prefetch(buffer_size=AUTOTUNE)

# %% [markdown]
# ### Create the model
# #### Todo: The RGB channel values are in the `[0, 255]` range. This is not ideal for a neural network. Here, it is good to standardize values to be in the `[0, 1]`

# %%
### Your code goes here

num_classes = 9 # As target class has 9 labels

model = Sequential([
  layers.experimental.preprocessing.Rescaling(1./255, input_shape=(img_height, img_width, 3)),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compile the model
# Choose an appropirate optimiser and loss function for model training

# %%
### Todo, choose an appropirate optimiser and loss function
model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %%
# View the summary of all layers
model.summary()
# Out:
# Model: "sequential"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  rescaling (Rescaling)       (None, 180, 180, 3)       0
#
#  conv2d (Conv2D)             (None, 180, 180, 16)      448
#
#  max_pooling2d (MaxPooling2D  (None, 90, 90, 16)       0
#  )
#
#  conv2d_1 (Conv2D)           (None, 90, 90, 32)        4640
#
#  max_pooling2d_1 (MaxPooling  (None, 45, 45, 32)       0
#  2D)
#
#  conv2d_2 (Conv2D)           (None, 45, 45, 64)        18496
#
#  max_pooling2d_2 (MaxPooling  (None, 22, 22, 64)       0
#  2D)
#
#  flatten (Flatten)           (None, 30976)             0
#
#  dense (Dense)               (None, 128)               3965056
#
#  dense_1 (Dense)             (None, 9)                 1161
#
# =================================================================
# Total params: 3,989,801
# Trainable params: 3,989,801
# Non-trainable params: 0
# _________________________________________________________________

# %% [markdown]
# ### Train the model

# %%
epochs = 20
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 254s 1s/step - loss: 2.0832 - accuracy: 0.2623 - val_loss: 1.7369 - val_accuracy: 0.4228
# Epoch 2/20
# 56/56 [==============================] - 1s 24ms/step - loss: 1.7622 - accuracy: 0.3722 - val_loss: 1.8109 - val_accuracy: 0.3378
# Epoch 3/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5874 - accuracy: 0.4381 - val_loss: 1.5189 - val_accuracy: 0.4787
# Epoch 4/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.5812 - accuracy: 0.4342 - val_loss: 1.5799 - val_accuracy: 0.4407
# Epoch 5/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.4724 - accuracy: 0.4805 - val_loss: 1.4203 - val_accuracy: 0.5168
# Epoch 6/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.3137 - accuracy: 0.5385 - val_loss: 1.4056 - val_accuracy: 0.5101
# Epoch 7/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.2450 - accuracy: 0.5592 - val_loss: 1.4299 - val_accuracy: 0.5190
# Epoch 8/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.1454 - accuracy: 0.5932 - val_loss: 1.5159 - val_accuracy: 0.5481
# Epoch 9/20
# 56/56 [==============================] - 1s 23ms/step - loss: 1.0606 - accuracy: 0.6373 - val_loss: 1.3689 - val_accuracy: 0.5727
# Epoch 10/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9915 - accuracy: 0.6479 - val_loss: 1.4655 - val_accuracy: 0.5503
# Epoch 11/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.9234 - accuracy: 0.6641 - val_loss: 1.6255 - val_accuracy: 0.5257
# Epoch 12/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.8456 - accuracy: 0.6964 - val_loss: 1.4872 - val_accuracy: 0.5213
# Epoch 13/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.7324 - accuracy: 0.7316 - val_loss: 1.6498 - val_accuracy: 0.5593
# Epoch 14/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.7336 - accuracy: 0.7433 - val_loss: 1.6661 - val_accuracy: 0.5056
# Epoch 15/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.6742 - accuracy: 0.7506 - val_loss: 1.5895 - val_accuracy: 0.5369
# Epoch 16/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5903 - accuracy: 0.7829 - val_loss: 1.7712 - val_accuracy: 0.5302
# Epoch 17/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.5381 - accuracy: 0.8069 - val_loss: 1.8902 - val_accuracy: 0.5526
# Epoch 18/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4734 - accuracy: 0.8337 - val_loss: 2.0410 - val_accuracy: 0.5436
# Epoch 19/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.4750 - accuracy: 0.8281 - val_loss: 2.3602 - val_accuracy: 0.4899
# Epoch 20/20
# 56/56 [==============================] - 1s 23ms/step - loss: 0.3897 - accuracy: 0.8527 - val_loss: 2.2051 - val_accuracy: 0.5481

# %% [markdown]
# ### Visualizing training results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(10, 10))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit

# %% [markdown]
# ### Write your findings here

# %% [markdown]
# **Comment:**
#
# - Training accuracy increased consistently, but validation accuracy was fixed around 50%
# - This is a clear indication of overfitting.
# - We can use data augmentation technique to increase the number of training images with slight modifications like rotating, flipping.

# %%
# Todo, after you have analysed the model fit history for presence of underfit or overfit, choose an appropriate data augumentation strategy. 


data_augmentation = keras.Sequential([
                                      layers.experimental.preprocessing.RandomFlip("horizontal", input_shape=(img_height, img_width, 3)),
                                      layers.experimental.preprocessing.RandomRotation(0.1),
                                      layers.experimental.preprocessing.RandomZoom(0.1),
])

# %%
print(data_augmentation)
# Out:
# <keras.engine.sequential.Sequential object at 0x7f59b299bb90>

# %%
# Todo, visualize how your augmentation strategy works for one instance of training image.

plt.figure(figsize=(10, 10))
for images, _ in train_ds.take(1):
  for i in range(9):
    augmented_images = data_augmentation(images)
    ax = plt.subplot(3, 3, i + 1)
    plt.imshow(augmented_images[0].numpy().astype("uint8"))
    plt.axis("off")

# %% [markdown]
# ### Todo:
# ### Create the model, compile and train the model

# %%
## You can use Dropout layer if there is an evidence of overfitting in your findings

## Your code goes here

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# ### Compiling the model

# %%
## Your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# ### Training the model

# %%
## Your code goes here, note: train your model for 20 epochs
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/20
# 56/56 [==============================] - 3s 29ms/step - loss: 1.9669 - accuracy: 0.2628 - val_loss: 1.8333 - val_accuracy: 0.3356
# Epoch 2/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.6844 - accuracy: 0.4029 - val_loss: 1.5529 - val_accuracy: 0.4698
# Epoch 3/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.5065 - accuracy: 0.4671 - val_loss: 1.4744 - val_accuracy: 0.5101
# Epoch 4/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.4407 - accuracy: 0.4972 - val_loss: 1.4122 - val_accuracy: 0.5123
# Epoch 5/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.4485 - accuracy: 0.4838 - val_loss: 1.4197 - val_accuracy: 0.5190
# Epoch 6/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3563 - accuracy: 0.5246 - val_loss: 1.3659 - val_accuracy: 0.5324
# Epoch 7/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.3137 - accuracy: 0.5363 - val_loss: 1.3754 - val_accuracy: 0.5168
# Epoch 8/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2887 - accuracy: 0.5469 - val_loss: 1.3320 - val_accuracy: 0.5548
# Epoch 9/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2467 - accuracy: 0.5603 - val_loss: 1.3574 - val_accuracy: 0.5503
# Epoch 10/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.2311 - accuracy: 0.5597 - val_loss: 1.3412 - val_accuracy: 0.5459
# Epoch 11/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.2445 - accuracy: 0.5497 - val_loss: 1.4287 - val_accuracy: 0.5369
# Epoch 12/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1970 - accuracy: 0.5725 - val_loss: 1.3746 - val_accuracy: 0.5414
# Epoch 13/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1924 - accuracy: 0.5742 - val_loss: 1.3002 - val_accuracy: 0.5481
# Epoch 14/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1464 - accuracy: 0.5859 - val_loss: 1.3024 - val_accuracy: 0.5503
# Epoch 15/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.1347 - accuracy: 0.5921 - val_loss: 1.2983 - val_accuracy: 0.5727
# Epoch 16/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1985 - accuracy: 0.5625 - val_loss: 1.3454 - val_accuracy: 0.5682
# Epoch 17/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.1266 - accuracy: 0.5954 - val_loss: 1.2968 - val_accuracy: 0.5839
# Epoch 18/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0805 - accuracy: 0.6177 - val_loss: 1.3427 - val_accuracy: 0.5638
# Epoch 19/20
# 56/56 [==============================] - 1s 26ms/step - loss: 1.0954 - accuracy: 0.6077 - val_loss: 1.3392 - val_accuracy: 0.5638
# Epoch 20/20
# 56/56 [==============================] - 1s 25ms/step - loss: 1.0594 - accuracy: 0.6161 - val_loss: 1.3293 - val_accuracy: 0.5839

# %% [markdown]
# ### Visualizing the results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### Todo: Write your findings after the model fit, see if there is an evidence of model overfit or underfit. Do you think there is some improvement now as compared to the previous model run?

# %% [markdown]
# **Comment:**
# - With the help of augmented data, the problem of overfitting is mitigated.
# - Training and validation accuracy of the above model are in the same range.
# - The model is performing poorly both on training data and validation data- i.e. the model is underfitting now.

# %% [markdown]
# #### **Todo:** Find the distribution of classes in the training dataset.
# #### **Context:** Many times real life datasets can have class imbalance, one class can have proportionately higher number of samples compared to the others. Class imbalance can have a detrimental effect on the final model quality. Hence as a sanity check it becomes important to check what is the distribution of classes in the data.

# %%
## Your code goes here.

from glob import glob
path_list = [ x for x in glob(os.path.join(data_dir_train, '*', '*.jpg')) ] 
lesion_list = [ os.path.basename(os.path.dirname(y)) for y in glob(os.path.join(data_dir_train, '*', '*.jpg')) ]
print(len(lesion_list))
# Out:
# 2239

# %%
df_dict_original = dict(zip(path_list, lesion_list))
print(list(df_dict_original.items())[:2])
# Out:
# [('/content/gdrive/MyDrive/Datasets/Melanoma/Train/actinic keratosis/ISIC_0029713.jpg', 'actinic keratosis'), ('/content/gdrive/MyDrive/Datasets/Melanoma/Train/actinic keratosis/ISIC_0030142.jpg', 'actinic keratosis')]

# %%
original_df = pd.DataFrame(list(df_dict_original.items()), columns=['Path','Label'])
original_df.head()
# Out:
#                                                 Path              Label
# 0  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 1  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 2  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 3  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 4  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis

# %%
original_df[['Label']].value_counts()
# Out:
# Label
# pigmented benign keratosis    462
# melanoma                      438
# basal cell carcinoma          376
# nevus                         357
# squamous cell carcinoma       181
# vascular lesion               139
# actinic keratosis             114
# dermatofibroma                 95
# seborrheic keratosis           77
# dtype: int64

# %%
original_df[['Label']].value_counts(normalize=True)*100
# Out:
# Label
# pigmented benign keratosis    20.634212
# melanoma                      19.562305
# basal cell carcinoma          16.793211
# nevus                         15.944618
# squamous cell carcinoma        8.083966
# vascular lesion                6.208129
# actinic keratosis              5.091559
# dermatofibroma                 4.242966
# seborrheic keratosis           3.439035
# dtype: float64

# %% [markdown]
# #### **Todo:** Write your findings here:
# #### - Which class has the least number of samples?
# #### - Which classes dominate the data in terms proportionate number of samples?

# %% [markdown]
# **Comment:**
# - 'seborrheic keratosis' has the least number of samples
# - the classes 'pigmented benign keratosis' and 'melanoma' dominate the data with 20.6% and 19.5% samples respectively.

# %% [markdown]
# #### **Todo:** Rectify the class imbalance
# #### **Context:** You can use a python package known as `Augmentor` (https://augmentor.readthedocs.io/en/master/) to add more samples across all classes so that none of the classes have very few samples.

# %%
# !pip install Augmentor
# Out:
# Collecting Augmentor
#   Downloading Augmentor-0.2.9-py2.py3-none-any.whl (38 kB)
# Requirement already satisfied: numpy>=1.11.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (1.21.6)
# Requirement already satisfied: future>=0.16.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (0.16.0)
# Requirement already satisfied: Pillow>=5.2.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (7.1.2)
# Requirement already satisfied: tqdm>=4.9.0 in /usr/local/lib/python3.7/dist-packages (from Augmentor) (4.64.0)
# Installing collected packages: Augmentor
# Successfully installed Augmentor-0.2.9

# %% [markdown]
# To use `Augmentor`, the following general procedure is followed:
#
# 1. Instantiate a `Pipeline` object pointing to a directory containing your initial image data set.<br>
# 2. Define a number of operations to perform on this data set using your `Pipeline` object.<br>
# 3. Execute these operations by calling the `Pipeline’s` `sample()` method.

# %%
path_to_training_dataset=str(data_dir_train) + '/'
import Augmentor
for i in class_names:
    p = Augmentor.Pipeline(path_to_training_dataset + i)
    p.rotate(probability=0.7, max_left_rotation=10, max_right_rotation=10)
    p.sample(500) ## We are adding 500 samples per class to make sure that none of the classes are sparse.
# Out:
# Initialised with 114 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/actinic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F59B23A3DD0>: 100%|██████████| 500/500 [00:19<00:00, 25.17 Samples/s]
# Initialised with 376 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/basal cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F59B23D3B10>: 100%|██████████| 500/500 [00:21<00:00, 23.30 Samples/s]
# Initialised with 95 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/dermatofibroma/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F59B23ED450>: 100%|██████████| 500/500 [00:22<00:00, 22.03 Samples/s]
# Initialised with 438 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/melanoma/output.
# Processing <PIL.Image.Image image mode=RGB size=3072x2304 at 0x7F59B2551E90>: 100%|██████████| 500/500 [01:35<00:00,  5.22 Samples/s]
# Initialised with 357 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/nevus/output.
# Processing <PIL.Image.Image image mode=RGB size=919x802 at 0x7F59B246F610>: 100%|██████████| 500/500 [01:24<00:00,  5.94 Samples/s]
# Initialised with 462 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/pigmented benign keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F59B23A3950>: 100%|██████████| 500/500 [00:17<00:00, 27.89 Samples/s]
# Initialised with 77 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/seborrheic keratosis/output.
# Processing <PIL.Image.Image image mode=RGB size=1024x768 at 0x7F59B23996D0>: 100%|██████████| 500/500 [00:42<00:00, 11.82 Samples/s]
# Initialised with 181 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/squamous cell carcinoma/output.
# Processing <PIL.Image.Image image mode=RGB size=600x450 at 0x7F59B2399990>: 100%|██████████| 500/500 [00:18<00:00, 27.35 Samples/s]
# Initialised with 139 image(s) found.
# Output directory set to /content/gdrive/MyDrive/Datasets/Melanoma/Train/vascular lesion/output.
# Processing <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=600x450 at 0x7F59B24374D0>: 100%|██████████| 500/500 [00:17<00:00, 27.99 Samples/s]

# %% [markdown]
# Augmentor has stored the augmented images in the output sub-directory of each of the sub-directories of skin cancer types.. Lets take a look at total count of augmented images.

# %%
image_count_train = len(list(data_dir_train.glob('*/output/*.jpg')))
print(image_count_train)
# Out:
# 4500

# %% [markdown]
# ### Lets see the distribution of augmented data after adding new images to the original training data.

# %%
path_list_new = [x for x in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
path_list_new[:2]
# Out:
# ['/content/gdrive/MyDrive/Datasets/Melanoma/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0027452.jpg_23046acb-a8b5-4e7b-b2e4-270a194cd779.jpg',
#  '/content/gdrive/MyDrive/Datasets/Melanoma/Train/actinic keratosis/output/actinic keratosis_original_ISIC_0026171.jpg_50ca66fd-7d00-4c49-89d8-3fb7f26309ab.jpg']

# %%
lesion_list_new = [os.path.basename(os.path.dirname(os.path.dirname(y))) for y in glob(os.path.join(data_dir_train, '*','output', '*.jpg'))]
lesion_list_new[:2]
# Out:
# ['actinic keratosis', 'actinic keratosis']

# %%
dataframe_dict_new = dict(zip(path_list_new, lesion_list_new))

# %%
df2 = pd.DataFrame(list(dataframe_dict_new.items()),columns = ['Path','Label'])
new_df = original_df.append(df2)
new_df.shape
# Out:
# (6739, 2)

# %%
new_df.head()
# Out:
#                                                 Path              Label
# 0  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 1  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 2  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 3  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis
# 4  /content/gdrive/MyDrive/Datasets/Melanoma/Trai...  actinic keratosis

# %%
# Checking the class distribution after adding 500 samples per label
new_df['Label'].value_counts(normalize=True)
# Out:
# pigmented benign keratosis    0.142751
# melanoma                      0.139190
# basal cell carcinoma          0.129990
# nevus                         0.127170
# squamous cell carcinoma       0.101054
# vascular lesion               0.094821
# actinic keratosis             0.091111
# dermatofibroma                0.088292
# seborrheic keratosis          0.085621
# Name: Label, dtype: float64

# %%
new_df['Label'].value_counts()
# Out:
# pigmented benign keratosis    962
# melanoma                      938
# basal cell carcinoma          876
# nevus                         857
# squamous cell carcinoma       681
# vascular lesion               639
# actinic keratosis             614
# dermatofibroma                595
# seborrheic keratosis          577
# Name: Label, dtype: int64

# %% [markdown]
# So, now we have added 500 images to all the classes to maintain some class balance. We can add more images as we want to improve training process.

# %% [markdown]
# #### **Todo**: Train the model on the data created using Augmentor

# %%
batch_size = 32
img_height = 180
img_width = 180

# %% [markdown]
# #### **Todo:** Create a training dataset

# %%
# if no changes made

# data_dir_train="path to directory with training data + data created using augmentor"
train_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'training',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 5392 files for training.

# %% [markdown]
# #### **Todo:** Create a validation dataset

# %%
val_ds = tf.keras.preprocessing.image_dataset_from_directory(
  data_dir_train,
  seed=123,
  validation_split = 0.2,
  subset = 'validation',
  image_size=(img_height, img_width),
  batch_size=batch_size)
# Out:
# Found 6739 files belonging to 9 classes.
# Using 1347 files for validation.

# %% [markdown]
# #### **Todo:** Create your model (make sure to include normalization)

# %%
## your code goes here

model = Sequential([
  data_augmentation,
  layers.experimental.preprocessing.Rescaling(1./255),
  layers.Conv2D(16, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(32, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Conv2D(64, 3, padding='same', activation='relu'),
  layers.MaxPooling2D(),
  layers.Dropout(0.2),
  layers.Flatten(),
  layers.Dense(128, activation='relu'),
  layers.Dense(num_classes)
])

# %% [markdown]
# #### **Todo:** Compile your model (Choose optimizer and loss function appropriately)

# %%
## your code goes here

model.compile(optimizer='adam',
              loss=tf.keras.losses.SparseCategoricalCrossentropy(from_logits=True),
              metrics=['accuracy'])

# %% [markdown]
# #### **Todo:**  Train your model

# %%
epochs = 30
## Your code goes here, use 50 epochs.
history = model.fit(
  train_ds,
  validation_data=val_ds,
  epochs=epochs
)
# Out:
# Epoch 1/30
# 169/169 [==============================] - 42s 240ms/step - loss: 1.7457 - accuracy: 0.3325 - val_loss: 1.5259 - val_accuracy: 0.4358
# Epoch 2/30
# 169/169 [==============================] - 30s 174ms/step - loss: 1.4568 - accuracy: 0.4458 - val_loss: 1.4104 - val_accuracy: 0.4655
# Epoch 3/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.3539 - accuracy: 0.4861 - val_loss: 1.3137 - val_accuracy: 0.5078
# Epoch 4/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.2842 - accuracy: 0.5069 - val_loss: 1.2943 - val_accuracy: 0.5219
# Epoch 5/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.2248 - accuracy: 0.5345 - val_loss: 1.2914 - val_accuracy: 0.5197
# Epoch 6/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.1628 - accuracy: 0.5588 - val_loss: 1.1065 - val_accuracy: 0.5768
# Epoch 7/30
# 169/169 [==============================] - 30s 171ms/step - loss: 1.1228 - accuracy: 0.5718 - val_loss: 1.0605 - val_accuracy: 0.5969
# Epoch 8/30
# 169/169 [==============================] - 30s 169ms/step - loss: 1.0687 - accuracy: 0.5974 - val_loss: 1.0775 - val_accuracy: 0.5895
# Epoch 9/30
# 169/169 [==============================] - 30s 170ms/step - loss: 1.0576 - accuracy: 0.6078 - val_loss: 1.0223 - val_accuracy: 0.6125
# Epoch 10/30
# 169/169 [==============================] - 38s 221ms/step - loss: 1.0072 - accuracy: 0.6187 - val_loss: 1.0290 - val_accuracy: 0.6214
# Epoch 11/30
# 169/169 [==============================] - 29s 169ms/step - loss: 0.9245 - accuracy: 0.6541 - val_loss: 1.1011 - val_accuracy: 0.6028
# Epoch 12/30
# 169/169 [==============================] - 29s 169ms/step - loss: 0.9103 - accuracy: 0.6593 - val_loss: 0.9613 - val_accuracy: 0.6385
# Epoch 13/30
# 169/169 [==============================] - 31s 175ms/step - loss: 0.8791 - accuracy: 0.6619 - val_loss: 1.1768 - val_accuracy: 0.5924
# Epoch 14/30
# 169/169 [==============================] - 29s 169ms/step - loss: 0.8125 - accuracy: 0.6986 - val_loss: 0.8234 - val_accuracy: 0.6949
# Epoch 15/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.8023 - accuracy: 0.7031 - val_loss: 1.0958 - val_accuracy: 0.6110
# Epoch 16/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.7691 - accuracy: 0.7149 - val_loss: 1.1093 - val_accuracy: 0.6140
# Epoch 17/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.7490 - accuracy: 0.7220 - val_loss: 0.8557 - val_accuracy: 0.6800
# Epoch 18/30
# 169/169 [==============================] - 30s 173ms/step - loss: 0.7102 - accuracy: 0.7311 - val_loss: 0.8778 - val_accuracy: 0.6711
# Epoch 19/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.6737 - accuracy: 0.7515 - val_loss: 0.8298 - val_accuracy: 0.6860
# Epoch 20/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.6682 - accuracy: 0.7491 - val_loss: 0.7630 - val_accuracy: 0.7164
# Epoch 21/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.6269 - accuracy: 0.7656 - val_loss: 0.7967 - val_accuracy: 0.7268
# Epoch 22/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.6046 - accuracy: 0.7773 - val_loss: 0.9785 - val_accuracy: 0.6585
# Epoch 23/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.6330 - accuracy: 0.7678 - val_loss: 0.8793 - val_accuracy: 0.6785
# Epoch 24/30
# 169/169 [==============================] - 30s 170ms/step - loss: 0.6112 - accuracy: 0.7706 - val_loss: 0.6706 - val_accuracy: 0.7446
# Epoch 25/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.5581 - accuracy: 0.7928 - val_loss: 0.7335 - val_accuracy: 0.7231
# Epoch 26/30
# 169/169 [==============================] - 30s 172ms/step - loss: 0.5476 - accuracy: 0.7960 - val_loss: 0.6795 - val_accuracy: 0.7550
# Epoch 27/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.5274 - accuracy: 0.8068 - val_loss: 0.7112 - val_accuracy: 0.7535
# Epoch 28/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.5145 - accuracy: 0.8110 - val_loss: 0.6548 - val_accuracy: 0.7550
# Epoch 29/30
# 169/169 [==============================] - 30s 171ms/step - loss: 0.4867 - accuracy: 0.8207 - val_loss: 0.6171 - val_accuracy: 0.7817
# Epoch 30/30
# 169/169 [==============================] - 30s 170ms/step - loss: 0.4760 - accuracy: 0.8253 - val_loss: 0.7790 - val_accuracy: 0.7513

# %% [markdown]
# #### **Todo:**  Visualize the model results

# %%
acc = history.history['accuracy']
val_acc = history.history['val_accuracy']

loss = history.history['loss']
val_loss = history.history['val_loss']

epochs_range = range(epochs)

plt.figure(figsize=(8, 8))
plt.subplot(1, 2, 1)
plt.plot(epochs_range, acc, label='Training Accuracy')
plt.plot(epochs_range, val_acc, label='Validation Accuracy')
plt.legend(loc='lower right')
plt.title('Training and Validation Accuracy')

plt.subplot(1, 2, 2)
plt.plot(epochs_range, loss, label='Training Loss')
plt.plot(epochs_range, val_loss, label='Validation Loss')
plt.legend(loc='upper right')
plt.title('Training and Validation Loss')
plt.show()

# %% [markdown]
# #### **Todo:**  Analyze your results here. Did you get rid of underfitting/overfitting? Did class rebalance help?

# %% [markdown]
# **Comment:**
# - In the final model, there is no sign of overfitting.
# - In 30 epochs, the final model is able to achieve more than 75% validation accuracy.
# - The low difference between the training accuracy and validation accuracy signifies that the final CNN model is able to generalize well.
